# %%
# %reload_ext autoreload
# %autoreload 2

# %%
# %pip install -U -qqqq langgraph uv databricks-agents databricks-langchain mlflow-skinny[databricks]
dbutils.library.restartPython()

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from agent import agent

# %%
config = {"configurable": {"thread_id": "1"}}
result = agent.invoke({"messages": [{"role": "user", "content": "greet Hera"}]}, config)
print(result['messages'][-1].content)

# %%
result = agent.invoke({"messages": [{"role": "user", "content": "What schema's contain the geolocation columns"}]}, config)
print(result['messages'][-1].content)

# %%
result = agent.invoke({"messages": [{"role": "user", "content": "any other tables in a different schema having them?"}]}, config)
print(result['messages'][-1].content)

# %%
result = agent.invoke({"messages": [{"role": "user", "content": "list the schemas"}]}, config)
print(result['messages'][-1].content)

# %%
result = agent.invoke({"messages": [{"role": "user", "content": "exit"}]}, config)
print(result['messages'][-1].content)

# %%
result = agent.invoke({"messages": [{"role": "user", "content": "Who am I?"}]}, config)
print(result['messages'][-1].content)
